# %%
import random

size = 5
bombs = 5

# Create board
board = [[' ' for _ in range(size)] for _ in range(size)]
for _ in range(bombs):
    while True:
        r, c = random.randint(0, size-1), random.randint(0, size-1)
        if board[r][c] != '💣':
            board[r][c] = '💣'
            break

# Add bomb counts
for i in range(size):
    for j in range(size):
        if board[i][j] == '💣':
            continue
        count = 0
        for x in range(max(0, i-1), min(size, i+2)):
            for y in range(max(0, j-1), min(size, j+2)):
                if board[x][y] == '💣':
                    count += 1
        board[i][j] = str(count)

# Game loop
dug = set()
while True:
    # Print board
    for i in range(size):
        row = ''
        for j in range(size):
            cell = board[i][j] if (i, j) in dug else '❓'
            row += cell + ' '
        print(row)

    # Get input
    try:
        r, c = map(int, input("🕹️ Enter row,col (e.g. 1,2): ").split(','))
        if r < 0 or r >= size or c < 0 or c >= size:
            print("⚠️ Out of bounds!")
            continue
        if board[r][c] == '💣':
            print("💥 Boom! Game Over.")
            break
        dug.add((r, c))
        if len(dug) == size * size - bombs:
            print("🎉 You cleared the board! You win!")
            break
    except:
        print("❌ Invalid input. Try again.")
# Out:
# ❓ ❓ ❓ ❓ ❓
# ❓ ❓ ❓ ❓ ❓
# ❓ ❓ ❓ ❓ ❓
# ❓ ❓ ❓ ❓ ❓
# ❓ ❓ ❓ ❓ ❓
# 🕹️ Enter row,col (e.g. 1,2): 1,2
# ❓ ❓ ❓ ❓ ❓
# ❓ ❓ 2 ❓ ❓
# ❓ ❓ ❓ ❓ ❓
# ❓ ❓ ❓ ❓ ❓
# ❓ ❓ ❓ ❓ ❓
# 🕹️ Enter row,col (e.g. 1,2): 2,3
# ❓ ❓ ❓ ❓ ❓
# ❓ ❓ 2 ❓ ❓
# ❓ ❓ ❓ 1 ❓
# ❓ ❓ ❓ ❓ ❓
# ❓ ❓ ❓ ❓ ❓
# 🕹️ Enter row,col (e.g. 1,2): 3,1
# ❓ ❓ ❓ ❓ ❓
# ❓ ❓ 2 ❓ ❓
# ❓ ❓ ❓ 1 ❓
# ❓ 2 ❓ ❓ ❓
# ❓ ❓ ❓ ❓ ❓
# 🕹️ Enter row,col (e.g. 1,2): 4,5
# ⚠️ Out of bounds!
# ❓ ❓ ❓ ❓ ❓
# ❓ ❓ 2 ❓ ❓
# ❓ ❓ ❓ 1 ❓
# ❓ 2 ❓ ❓ ❓
# ❓ ❓ ❓ ❓ ❓
# 🕹️ Enter row,col (e.g. 1,2): 1,1
# ❓ ❓ ❓ ❓ ❓
# ❓ 3 2 ❓ ❓
# ❓ ❓ ❓ 1 ❓
# ❓ 2 ❓ ❓ ❓
# ❓ ❓ ❓ ❓ ❓
# 🕹️ Enter row,col (e.g. 1,2): 5,5
# ⚠️ Out of bounds!
# ❓ ❓ ❓ ❓ ❓
# ❓ 3 2 ❓ ❓
# ❓ ❓ ❓ 1 ❓
# ❓ 2 ❓ ❓ ❓
# ❓ ❓ ❓ ❓ ❓
# 🕹️ Enter row,col (e.g. 1,2): 3,1
# ❓ ❓ ❓ ❓ ❓
# ❓ 3 2 ❓ ❓
# ❓ ❓ ❓ 1 ❓
# ❓ 2 ❓ ❓ ❓
# ❓ ❓ ❓ ❓ ❓
# 🕹️ Enter row,col (e.g. 1,2): 1,3
